# %%
import os

# %%
os.listdir()
# Out:
# ['sample_submission.csv',
#  'test.csv',
#  '.ipynb_checkpoints',
#  'train.csv',
#  'sample_submission.csv.gz',
#  'description.txt',
#  'train.csv.gz',
#  'test.csv.gz',
#  'Untitled.ipynb']

# %%
import pandas

# %%
data = pandas.read_csv("train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df = data.dropna(thresh=len(data)-10,axis='columns') #drop all columns (axis = 1 or 'columns' ) with more than len(DATA) - 1 NaN values

# %%
df.shape
# Out:
# (1460, 65)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl    ...                0         0           0        0
# 1       FR2       Gtl    ...                0         0           0        0
# 2    Inside       Gtl    ...                0         0           0        0
# 3    Corner       Gtl    ...              272         0           0        0
# 4       FR2       Gtl    ...                0         0           0        0
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# 5        6          50       RL    14115   Pave      IR1         Lvl
# 6        7          20       RL    10084   Pave      Reg         Lvl
# 7        8          60       RL    10382   Pave      IR1         Lvl
# 8        9          50       RM     6120   Pave      Reg         Lvl
# 9       10         190       RL     7420   Pave      Reg         Lvl
# 10      11          20       RL    11200   Pave      Reg         Lvl
# 11      12          60       RL    11924   Pave      IR1         Lvl
# ...

# %%
y = df['SalePrice']

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
x = df[['MSSubClass','LotArea','OverallQual','OverallCond','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]

# %%
x.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  1stFlrSF  \
# 0          60     8450            7            5       2003       856
# 1          20     9600            6            8       1976      1262
# 2          60    11250            7            5       2001       920
# 3          70     9550            7            5       1915       961
# 4          60    14260            8            5       2000      1145
#
#    2ndFlrSF  FullBath  BedroomAbvGr  TotRmsAbvGrd
# 0       854         2             3             8
# 1         0         2             3             6
# 2       866         2             3             6
# 3       756         1             3             7
# 4      1053         2             4             9

# %%
from sklearn.tree import DecisionTreeRegressor as  DTR

# %%
model = DTR()
model.fit(x,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
print(x.head())
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  1stFlrSF  \
# 0          60     8450            7            5       2003       856
# 1          20     9600            6            8       1976      1262
# 2          60    11250            7            5       2001       920
# 3          70     9550            7            5       1915       961
# 4          60    14260            8            5       2000      1145
#
#    2ndFlrSF  FullBath  BedroomAbvGr  TotRmsAbvGrd
# 0       854         2             3             8
# 1         0         2             3             6
# 2       866         2             3             6
# 3       756         1             3             7
# 4      1053         2             4             9

# %%
model.predict(x)
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %%
#mean absolute error of decision tree
from sklearn.metrics import mean_absolute_error
pprice=model.predict(x)
error=mean_absolute_error(y,pprice)
error
# Out:
# 23.1420091324201

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both predictors and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_x, val_x, train_y, val_y = train_test_split(x, y,random_state = 0)
model = DTR()
# Fit model
model.fit(train_x, train_y)
# get predicted prices on validation data
val_predictions = model.predict(val_x)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 27643.646575342467

# %%
from sklearn.metrics import mean_absolute_error


def get_mae(max_leaf_nodes, predictors_train, predictors_val, targ_train, targ_val):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(predictors_train, targ_train)
    preds_val = model.predict(predictors_val)
    mae = mean_absolute_error(targ_val, preds_val)
    return(mae)
# compare MAE with differing values of max_leaf_nodes : values from 5 -> 5000 , step is 2 
max_leaf_nodesList = []
for max_leaf_nodes in range(5,5000,2):
    my_mae = get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y)
    max_leaf_nodesList.append((my_mae,max_leaf_nodes))
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  32224
# Max leaf nodes: 7  		 Mean Absolute Error:  31004
# Max leaf nodes: 9  		 Mean Absolute Error:  29643
# Max leaf nodes: 11  		 Mean Absolute Error:  27318
# Max leaf nodes: 13  		 Mean Absolute Error:  27529
# Max leaf nodes: 15  		 Mean Absolute Error:  27369
# Max leaf nodes: 17  		 Mean Absolute Error:  26248
# Max leaf nodes: 19  		 Mean Absolute Error:  26483
# Max leaf nodes: 21  		 Mean Absolute Error:  26533
# Max leaf nodes: 23  		 Mean Absolute Error:  26314
# Max leaf nodes: 25  		 Mean Absolute Error:  26508
# Max leaf nodes: 27  		 Mean Absolute Error:  26726
# Max leaf nodes: 29  		 Mean Absolute Error:  26294
# Max leaf nodes: 31  		 Mean Absolute Error:  26185
# Max leaf nodes: 33  		 Mean Absolute Error:  25928
# Max leaf nodes: 35  		 Mean Absolute Error:  25945
# Max leaf nodes: 37  		 Mean Absolute Error:  26054
# Max leaf nodes: 39  		 Mean Absolute Error:  26035
# ...

# %%
max_leaf_nodesList.sort()

# %%
max_leaf_nodesList #best accuracy for 71
# Out:
# [(24751.443904749267, 71),
#  (24916.153537533886, 73),
#  (25050.736409412744, 75),
#  (25149.54022133983, 69),
#  (25189.909721320102, 113),
#  (25198.584354618222, 77),
#  (25200.836136430604, 103),
#  (25228.820473943666, 107),
#  (25239.694169987615, 81),
#  (25240.190090794575, 179),
#  (25262.059431565114, 79),
#  (25267.494142132404, 109),
#  (25269.24272983719, 101),
#  (25281.33544166441, 99),
#  (25290.025306515967, 111),
#  (25298.297876808945, 105),
#  (25305.402399823415, 61),
#  (25318.165450688768, 123),
#  (25332.55167872232, 125),
#  (25339.45921618973, 177),
#  (25341.71814323058, 95),
#  (25342.097629898224, 115),
#  (25343.575880966717, 63),
#  (25348.436513044548, 173),
#  (25366.81141467618, 181),
#  (25367.995958618656, 127),
#  (25373.502407512227, 129),
#  (25378.62207768136, 175),
#  (25379.953112789182, 97),
#  (25391.95095201619, 187),
#  (25392.271105764292, 119),
#  (25392.271105764292, 121),
#  (25403.766579316038, 171),
#  (25408.11735074923, 183),
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor()
forest_model.fit(train_x, train_y)
pred = forest_model.predict(val_x)
h=mean_absolute_error(val_y, pred)
print(h)
#MAE using random forest
# Out:
# 20504.128675799086

# %%
#ACCURACY OF MODEL
z=(h/y.mean())
print(100-100*z)
# Out:
# 88.66681785133733

# %%
data=pandas.read_csv("test.csv")
data.head()
df=data.dropna(thresh=len(data)-10,axis=1)
#df.head()
df.dropna(axis=0)
#y=df.SalePrice
ppc=df[['MSSubClass','LotArea','OverallQual','OverallCond','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]
predictedprices = forest_model.predict(ppc)
print(predictedprices)
# Out:
# [127225.  163547.  163593.2 ... 152340.  136915.  235415. ]

# %%
my_submission = pandas.DataFrame({'Id': data.Id, 'SalePrice': predictedprices})
# you could use any filename. We choose submission here
my_submission.to_csv('submission.csv', index=False)
